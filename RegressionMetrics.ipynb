# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopalchalak/machineLearning/blob/main/RegressionMetrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("placement.csv")
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x = df.iloc[: , 0:1]
y = df.iloc[ :, -1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state = 2, test_size= 0.2)

# %%
plt.scatter(x,y)
plt.xlabel("CGPA")
plt.ylabel("Package(lpa)")
# Out:
# Text(0, 0.5, 'Package(lpa)')

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x,y)
plt.plot(x_train, lr.predict(x_train),color = "red")
plt.xlabel("CGPA")
plt.ylabel("Package(lpa)")
# Out:
# Text(0, 0.5, 'Package(lpa)')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, accuracy_score

# %%
y_pre = lr.predict(x_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE : ", mean_absolute_error(y_test, y_pre))
# Out:
# MAE :  0.2884710931878175

# %%
print("MSA: ", mean_squared_error(y_test, y_pre))
# Out:
# MSA:  0.12129235313495527

# %%
print("RMSA: ", np.sqrt(mean_squared_error(y_test, y_pre)))
# Out:
# RMSA:  0.34827051717731616

# %%
print("R2 Score: ", r2_score(y_test, y_pre))
# Out:
# R2 Score:  0.780730147510384
