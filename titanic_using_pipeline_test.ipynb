# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopalchalak/machineLearning/blob/main/titanic_using_pipeline_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open("/content/sample_data/pipe.pkl",'rb'))

# %%
# Assume user input
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import pandas as pd

# Assuming the order of features is Pclass, Sex, Age, SibSp, Parch, Fare, Embarked
# These column names should ideally match those used during the model training.
feature_names = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

# Convert the NumPy array to a pandas DataFrame with feature names
test_input_df = pd.DataFrame(test_input2, columns=feature_names)

# Make the prediction using the DataFrame
prediction = pipe.predict(test_input_df)
display(prediction)
# Out:
# array([0])
