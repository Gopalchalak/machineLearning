# %% [markdown]
# <a href="https://colab.research.google.com/github/Gopalchalak/machineLearning/blob/main/EDAUnivariateAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df= pd.read_csv("/content/sample_data/train.csv")

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 714          715         0       2          Greenberg, Mr. Samuel    male
# 718          719         0       3            McEvoy, Mr. Michael    male
# 211          212         1       2     Cameron, Miss. Clear Annie  female
# 433          434         0       3     Kallio, Mr. Nikolai Erland    male
# 488          489         0       3  Somerton, Mr. Francis William    male
#
#       Age  SibSp  Parch             Ticket    Fare Cabin Embarked
# 714  52.0      0      0             250647  13.000   NaN        S
# 718   NaN      0      0              36568  15.500   NaN        Q
# 211  35.0      0      0       F.C.C. 13528  21.000   NaN        S
# 433  17.0      0      0  STON/O 2. 3101274   7.125   NaN        S
# 488  30.0      0      0         A.5. 18509   8.050   NaN        S

# %%
df["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
# sns.countplot(data=df,x=df["Survived"])
sns.countplot(data=df, x=df["Pclass"], palette="Set1")
# Out:
# /tmp/ipython-input-2513564271.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=df["Pclass"], palette="Set1")
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# df['Pclass'].value_counts().plot(kind="pie", autopct="%.2f")
df['Survived'].value_counts().plot(kind="pie", autopct = "%.02f")
# df['Embarked'].value_counts().plot(kind="pie", autopct = "%.02f")
# df['Sex'].value_counts().plot(kind="pie", autopct = "%.02f")
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df["Age"])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df, x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
# df["Fare"].min()
df["Fare"].max()
print(df['Fare'].mean())
# Out:
# 32.204207968574636

# %%
sns.displot(df, x=df['Age'])
# Out:
# /tmp/ipython-input-2570896978.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df, x=df['Age'])
# <Axes: ylabel='Density'>
